# %%
import pandas as pd
import os

# %%
pwd=os.getcwd()

# %%
first_import = pd.read_csv(pwd + "\simple_csv.csv")

# %%
first_import["Column1"]
# Out:
# 0     0.280925
# 1     0.719882
# 2     0.235752
# 3     0.603366
# 4     0.039985
# 5     0.015478
# 6     0.192540
# 7     0.380921
# 8     0.592471
# 9     0.072112
# 10    0.898072
# 11    0.722038
# 12    0.513517
# 13    0.436729
# 14    0.864039
# 15    0.724761
# 16    0.198926
# 17    0.748500
# 18    0.920639
# 19    0.452024
# 20    0.542977
# 21    0.355266
# 22    0.142688
# 23    0.850436
# 24    0.443476
# 25    0.467100
# 26    0.338536
# 27    0.942101
# 28    0.570130
# Name: Column1, dtype: float64

# %%
#create new colum
first_import["new_colum"]= list(range(29))
first_import["Columna_a_borrar"] = 1
first_import
# Out:
#      Column1   Column2   Column3  new_colum  Columna_a_borrar
# 0   0.280925  0.910368  0.692982          0                 1
# 1   0.719882  0.210024  0.761276          1                 1
# 2   0.235752  0.059796  0.154667          2                 1
# 3   0.603366  0.485614  0.013345          3                 1
# 4   0.039985  0.236359  0.811832          4                 1
# 5   0.015478  0.543641  0.112719          5                 1
# 6   0.192540  0.409874  0.875082          6                 1
# 7   0.380921  0.045468  0.515859          7                 1
# 8   0.592471  0.786421  0.047249          8                 1
# 9   0.072112  0.695694  0.409573          9                 1
# 10  0.898072  0.070956  0.209020         10                 1
# 11  0.722038  0.211985  0.324164         11                 1
# 12  0.513517  0.091548  0.664279         12                 1
# 13  0.436729  0.040322  0.548167         13                 1
# ...

# %%
first_import = first_import.drop(columns="Columna_a_borrar")  #-- > esta desactivado porque ya la borre xd // no hace falta el =  si pónes ,inplace=true
first_import
# Out:
#      Column1   Column2   Column3  new_colum
# 0   0.280925  0.910368  0.692982          0
# 1   0.719882  0.210024  0.761276          1
# 2   0.235752  0.059796  0.154667          2
# 3   0.603366  0.485614  0.013345          3
# 4   0.039985  0.236359  0.811832          4
# 5   0.015478  0.543641  0.112719          5
# 6   0.192540  0.409874  0.875082          6
# 7   0.380921  0.045468  0.515859          7
# 8   0.592471  0.786421  0.047249          8
# 9   0.072112  0.695694  0.409573          9
# 10  0.898072  0.070956  0.209020         10
# 11  0.722038  0.211985  0.324164         11
# 12  0.513517  0.091548  0.664279         12
# 13  0.436729  0.040322  0.548167         13
# 14  0.864039  0.963556  0.106398         14
# 15  0.724761  0.410422  0.587589         15
# 16  0.198926  0.245207  0.767356         16
# 17  0.748500  0.019264  0.046678         17
# 18  0.920639  0.212611  0.520463         18
# 19  0.452024  0.123660  0.847451         19
# ...

# %%
#para importar filas especificas ej 1 a 6, 
first_import.loc[:5]
# Out:
#     Column1   Column2   Column3  new_colum
# 0  0.280925  0.910368  0.692982          0
# 1  0.719882  0.210024  0.761276          1
# 2  0.235752  0.059796  0.154667          2
# 3  0.603366  0.485614  0.013345          3
# 4  0.039985  0.236359  0.811832          4
# 5  0.015478  0.543641  0.112719          5

# %%
#usando una "," podes importar las columnas por el nombre ej; 
first_import.loc[:5,["Column1","Column3"]]
# Out:
#     Column1   Column3
# 0  0.280925  0.692982
# 1  0.719882  0.761276
# 2  0.235752  0.154667
# 3  0.603366  0.013345
# 4  0.039985  0.811832
# 5  0.015478  0.112719

# %%
#usando el iloc es igual que el anterior pero con el index de las columnas
first_import.iloc[:6,[0,2]]
# Out:
#     Column1   Column3
# 0  0.280925  0.692982
# 1  0.719882  0.761276
# 2  0.235752  0.154667
# 3  0.603366  0.013345
# 4  0.039985  0.811832
# 5  0.015478  0.112719

# %%
netflix = pd.read_csv(pwd + "\\netflix_titles.csv")
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
list(netflix.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
netflix.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
netflix["type"].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
#filter
netflix[(netflix["country"] == "Argentina") & (netflix["rating"]=="TV-MA")]
# Out:
#      show_id     type                                   title  \
# 92       s93    Movie             27, el club de los malditos
# 291     s292    Movie                                Abzurdah
# 344     s345    Movie             Agustín Aristarán: Soy Rada
# 426     s427  TV Show                            Almost Happy
# 558     s559  TV Show        Apache: The Life of Carlos Tevez
# 1167   s1168    Movie                         Caida del Cielo
# 1713   s1714    Movie                                  Desire
# 1924   s1925  TV Show                                    Edha
# 1959   s1960  TV Show                             El Marginal
# 2148   s2149    Movie                Fernando Sanjiao: Hombre
# 2537   s2538    Movie  Grego Rossello: Disculpe las molestias
# 2749   s2750  TV Show                     Historia de un clan
# 2884   s2885    Movie                             Hypersomnia
# 3035   s3036    Movie                               Intuition
# ...

# %%
#datetime 
computer_date =pd.to_datetime(netflix["date_added"])
netflix["computer_date"]=computer_date 
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
filer_netflix =netflix.groupby("country")["show_id"].count().reset_index()
filer_netflix.sort_values(by="show_id", ascending=False)
# Out:
#                                country  show_id
# 549                      United States     2555
# 229                              India      923
# 462                     United Kingdom      397
# 291                              Japan      226
# 394                        South Korea      183
# ..                                 ...      ...
# 252  Indonesia, South Korea, Singapore        1
# 253          Indonesia, United Kingdom        1
# 254           Indonesia, United States        1
# 255                       Iran, France        1
# 680                           Zimbabwe        1
#
# [681 rows x 2 columns]
